# %%
nom_variable = 3

# %%
nom_variable
# Out:
# 3

# %%
print(nom_variable)
# Out:
# 3

# %%
type(nom_variable)
# Out:
# int

# %%
a="Hello world"

# %%
a
# Out:
# 'Hello world'

# %%
type(a)
# Out:
# str
