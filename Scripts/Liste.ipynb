# %%
Liste = [2,0,1,6]

# %%
Liste.sort()

# %%
print(Liste)
# Out:
# [0, 1, 2, 6]

# %%
Liste.append(["hi","hello"])
print(Liste)
# Out:
# [0, 1, 2, 6, ['hi', 'hello']]

# %%
Liste = [2,0,1,6]
Liste
# Out:
# [2, 0, 1, 6]

# %%
Liste = [2,0,1,6]
Liste.extend(["hi","hello"])
print(Liste)
# Out:
# [2, 0, 1, 6, 'hi', 'hello']

# %%
Liste.count(2)
# Out:
# 1

# %%
a, b = 1, 2

# %%
a
# Out:
# 1

# %%
type(a)
# Out:
# int

# %%
c, d= (3, 4)
type(c)
# Out:
# int

# %%
type((c,d))
# Out:
# tuple

# %%
Panier = {"orange","poire","banane"}
print(Panier)
# Out:
# {'orange', 'banane', 'poire'}

# %%
"poire" in Panier
# Out:
# True

# %%
"Poire" in Panier
# Out:
# False

# %%
"poire " in Panier
# Out:
# False

# %%
Magie = set("abracadabra")
print(Magie)
# Out:
# {'d', 'a', 'b', 'c', 'r'}

# %%
Magie2= set("alcazam")
print(Magie2)
# Out:
# {'a', 'c', 'z', 'l', 'm'}

# %%
print(Magie & Magie2)
# Out:
# {'a', 'c'}

# %%
print(Magie | Magie2)
# Out:
# {'d', 'a', 'b', 'c', 'r', 'z', 'l', 'm'}

# %%
print(Magie - Magie2)
# Out:
# {'r', 'b', 'd'}
